# %% [markdown]
# <a href="https://colab.research.google.com/github/nadaoteif/VisualizationsAsgmt1/blob/main/Visualizations22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
maths_data = pd.read_csv("/content/Maths.csv")
maths_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#  Line Chart
plt.figure(figsize=(20,10))
plt.title("Absences")
sns.lineplot(data=maths_data['absences'])
plt.xlabel("absences")
# Out:
# Text(0.5, 0, 'absences')

# %%
#  Bar Chart
plt.figure(figsize=(20,10))
sns.barplot(x=maths_data['Mjob'], y=maths_data.index)
plt.xlabel("Mathores Job")
plt.title("maths_data")
# Out:
# Text(0.5, 1.0, 'maths_data')

# %%
#  Scatter Plot
plt.figure(figsize=(20,10))
plt.title("Absences")
plt.xlabel("Age")
sns.scatterplot(x=maths_data['age'], y=maths_data['school'])

# %%
#  Pie Chart
plt.figure(figsize=(20,10))
maths_data['sex'].value_counts().head(10).plot.pie()
plt.gca().set_aspect('equal')
plt.title("Sex of student's school")
# Out:
# Text(0.5, 1.0, "Sex of student's school")

# %%
#  Histogram
plt.figure(figsize=(20,10))
plt.title("health students")
sns.histplot(maths_data['health'])
plt.xlabel("number")
# Out:
# Text(0.5, 0, 'number')

# %%
#  Boxplot
plt.figure(figsize=(20,10))
plt.title("Freetime of students")
plt.boxplot(maths_data['freetime'])
plt.xlabel("hours")
# Out:
# Text(0.5, 0, 'hours')

# %%
# subplot
plt.figure(figsize=(20,10))

plt.subplot(2,2,1)
sns.barplot(x=maths_data['Mjob'], y=maths_data.index)
plt.xlabel("Mathores Job")

plt.subplot(2,2,2)
sns.histplot(maths_data['health'])

plt.subplot(2,2,3)
maths_data['sex'].value_counts().head(10).plot.pie()
plt.gca().set_aspect('equal')

plt.subplot(2,2,4)
sns.lineplot(data=maths_data['absences'])
plt.xlabel("absences")
# Out:
# Text(0.5, 0, 'absences')
